# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Cleaning df_final_demo

# %%
path3 = "https://raw.githubusercontent.com/gabriela-cl/vanguard-ab-test/main/data/raw/df_final_demo.csv"
df_final_demo = pd.read_csv(path3, sep=';')
pd.set_option('display.max_columns', None)
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
df_final_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB

# %%
df_final_demo.isnull().any()
# Out:
# client_id           False
# clnt_tenure_yr       True
# clnt_tenure_mnth     True
# clnt_age             True
# gendr                True
# num_accts            True
# bal                  True
# calls_6_mnth         True
# logons_6_mnth        True
# dtype: bool

# %%
df_final_demo["gendr"].unique()
# Out:
# array(['U', 'M', 'F', nan, 'X'], dtype=object)

# %%
df_final_demo.duplicated().sum()
# Out:
# 0

# %%
df_final_demo.isnull().sum().sort_values(ascending=False)
# Out:
# clnt_age            15
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# client_id            0
# dtype: int64

# %%
df_final_demo.columns[df_final_demo.isnull().mean() > 0.8]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## Demographics

# %%
df_final_demo["clnt_tenure_yr"].describe().round(2)
# Out:
# count    70595.00
# mean        12.05
# std          6.87
# min          2.00
# 25%          6.00
# 50%         11.00
# 75%         16.00
# max         62.00
# Name: clnt_tenure_yr, dtype: float64

# %%
bins = [1, 5, 10, 20, 30, 40, df_final_demo["clnt_tenure_yr"].max()]
labels = ['1 to 5', '6 to 10', '11 to 20', '21 to 30', '31 to 40', '41 or more']
df_final_demo['Clients Ternure (years)'] = pd.cut(df_final_demo["clnt_tenure_yr"], bins=bins, labels = labels, include_lowest=True)

# %%
sns.barplot(x =df_final_demo['Clients Ternure (years)'].value_counts().index, y = df_final_demo['Clients Ternure (years)'].value_counts().values, color="lightgreen")
# Out:
# <Axes: xlabel='Clients Ternure (years)'>

# %%
df_final_demo["clnt_age"].describe().round(2)
# Out:
# count    70594.00
# mean        46.44
# std         15.59
# min         13.50
# 25%         32.50
# 50%         47.00
# 75%         59.00
# max         96.00
# Name: clnt_age, dtype: float64

# %%
bins = [10, 20, 40, 60, 80, 100]
labels = ['10 to 20', '21 to 40', '41 to 60', '61 to 80', '81 to 100']
df_final_demo['Clients Age'] = pd.cut(df_final_demo["clnt_age"], bins=bins, labels = labels, include_lowest=True)

# %%
sns.barplot(x =df_final_demo['Clients Age'].value_counts().index, y = df_final_demo['Clients Age'].value_counts().values, color="salmon")
# Out:
# <Axes: xlabel='Clients Age'>

# %%
df_final_demo["gendr"].describe()
# Out:
# count     70595
# unique        4
# top           U
# freq      24122
# Name: gendr, dtype: object

# %%
df_final_demo["gendr"].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
# Filter the DataFrame for 'M' and 'F' genders only
filtered_df = df_final_demo[df_final_demo['gendr'].isin(['M', 'F', 'U'])]

# %%
sns.countplot(x='gendr', data=filtered_df, hue = 'gendr', palette=['lightblue', 'salmon', 'lightgreen'])

plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.xticks(ticks=[0, 1, 2], labels=['Male', 'Female', 'Unknow'])
# Out:
# ([<matplotlib.axis.XTick at 0x14b784410>,
#   <matplotlib.axis.XTick at 0x14b798390>,
#   <matplotlib.axis.XTick at 0x13f8a3d50>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female'), Text(2, 0, 'Unknow')])

# %% [markdown]
# ## Data Web

# %%
path_1= "https://raw.githubusercontent.com/Mancini997/vanguard-ab-test/main/data/raw/df_final_web_data_pt_1.csv"
df_web_1 = pd.read_csv(path_1,sep=';')
path_2= "https://raw.githubusercontent.com/Mancini997/vanguard-ab-test/main/data/raw/df_final_web_data_pt_2.csv"
df_web_2 = pd.read_csv(path_2,sep=';')

path_3 = "https://raw.githubusercontent.com/Mancini997/vanguard-ab-test/main/data/raw/df_final_demo.csv"

df_final_demo = pd.read_csv(path_3, sep=';')

path_4 ='https://raw.githubusercontent.com/data-bootcamp-v4/lessons/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt'
final_experiment = pd.read_csv(path_4, sep=',')
pd.set_option('display.max_columns', None)

# %%
#Merging the Web dataframe in we_df.
web_df =pd.concat([df_web_1, df_web_2], axis=0, join="inner")

# %%
web_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [755405 rows x 5 columns]

# %%
web_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755405 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.6+ MB

# %%
web_df['date_time'] = pd.to_datetime(web_df['date_time'])

# %%
web_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755405 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.6+ MB

# %%
web_df['process_step'].unique()
# Out:
# array(['step_3', 'step_2', 'step_1', 'start', 'confirm'], dtype=object)

# %%
# Define the required steps
required_steps = set(['step_3', 'step_2', 'step_1', 'start', 'confirm'])

# Function to check if all steps are present in a visit_id group
def has_all_steps(group):
    steps = set(group['process_step'])
    return steps == required_steps

# Group by visit_id and apply the function
results = web_df.groupby('visit_id').apply(has_all_steps).reset_index()

# Rename columns for clarity
results.columns = ['visit_id', 'contains_all_steps']

print(results)
# Out:
#                             visit_id  contains_all_steps
# 0       100012776_37918976071_457913               False
# 1          1000165_4190026492_760066                True
# 2        100019538_17884295066_43909                True
# 3       100022086_87870757897_149620                True
# 4       100030127_47967100085_936361               False
# ...                              ...                 ...
# 158090  999986292_55082159911_561557               False
# 158091  999988789_76411676596_272843               False
# 158092  999989069_52203656268_170206               False
# 158093  999991142_15352368745_399725               False
# 158094  999992932_41666455053_671149                True
#
# [158095 rows x 2 columns]

# %%
# Function to calculate the visit duration
def visit_duration(group):
    start_time = group['date_time'].min()
    end_time = group['date_time'].max()
    duration = end_time - start_time
    return duration

# Group by visit_id and calculate the duration
visit_durations = web_df.groupby('visit_id').apply(visit_duration).reset_index()

# Rename columns for clarity
visit_durations.columns = ['visit_id', 'visit_duration']

print(visit_durations)
# Out:
#                             visit_id  visit_duration
# 0       100012776_37918976071_457913 0 days 00:00:52
# 1          1000165_4190026492_760066 0 days 00:02:21
# 2        100019538_17884295066_43909 0 days 00:04:02
# 3       100022086_87870757897_149620 0 days 00:03:00
# 4       100030127_47967100085_936361 0 days 00:00:00
# ...                              ...             ...
# 158090  999986292_55082159911_561557 0 days 00:31:35
# 158091  999988789_76411676596_272843 0 days 00:01:58
# 158092  999989069_52203656268_170206 0 days 00:00:04
# 158093  999991142_15352368745_399725 0 days 00:00:00
# 158094  999992932_41666455053_671149 0 days 00:19:31
#
# [158095 rows x 2 columns]

# %%
merged_log_visit = pd.merge(df_final_demo[['client_id', 'clnt_tenure_mnth', 'clnt_age', 'logons_6_mnth']], 
                     web_df[['client_id', 'visit_id']], 
                     on='client_id', 
                     how='inner')

# %%
merged_log_visit
# Out:
#         client_id  clnt_tenure_mnth  clnt_age  logons_6_mnth  \
# 0          836976              73.0      60.5            9.0
# 1          836976              73.0      60.5            9.0
# 2          836976              73.0      60.5            9.0
# 3          836976              73.0      60.5            9.0
# 4          836976              73.0      60.5            9.0
# ...           ...               ...       ...            ...
# 449826    5602139             254.0      59.5            7.0
# 449827    5602139             254.0      59.5            7.0
# 449828    5602139             254.0      59.5            7.0
# 449829    5602139             254.0      59.5            7.0
# 449830    5602139             254.0      59.5            7.0
#
#                             visit_id
# 0        228976764_46825473280_96584
# 1        228976764_46825473280_96584
# 2        228976764_46825473280_96584
# 3        228976764_46825473280_96584
# 4        228976764_46825473280_96584
# ...                              ...
# 449826    158544612_4105226940_43043
# 449827    158544612_4105226940_43043
# 449828    158544612_4105226940_43043
# 449829  884309593_49820690623_654151
# 449830  884309593_49820690623_654151
#
# [449831 rows x 5 columns]

# %%
merged_log_visit.isnull().sum().sort_values(ascending=False)
# Out:
# clnt_age            127
# clnt_tenure_mnth    115
# logons_6_mnth       115
# client_id             0
# visit_id              0
# dtype: int64

# %%
merged_log_visit.duplicated().sum()
# Out:
# 352595

# %%
log_no_duplicates = merged_log_visit.drop_duplicates()

# %%
log_no_duplicates
# Out:
#         client_id  clnt_tenure_mnth  clnt_age  logons_6_mnth  \
# 0          836976              73.0      60.5            9.0
# 7          836976              73.0      60.5            9.0
# 11        2304905              94.0      58.0            9.0
# 17        1439522              64.0      32.0            9.0
# 21        1439522              64.0      32.0            9.0
# ...           ...               ...       ...            ...
# 449820    1573142             255.0      68.0            4.0
# 449821    1573142             255.0      68.0            4.0
# 449823    1573142             255.0      68.0            4.0
# 449826    5602139             254.0      59.5            7.0
# 449829    5602139             254.0      59.5            7.0
#
#                             visit_id
# 0        228976764_46825473280_96584
# 7        104438405_2368283624_817211
# 11      724930510_65323235593_692754
# 17      898099666_87299892721_263146
# 21       968288276_7230824336_666089
# ...                              ...
# 449820  709721715_35968917131_979675
# 449821   326174177_47892407008_51741
# 449823  448875043_84914821939_263970
# 449826    158544612_4105226940_43043
# 449829  884309593_49820690623_654151
#
# [97236 rows x 5 columns]

# %% [markdown]
# ## Final Experiment

# %%
final_experiment
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
final_experiment.isnull().sum().sort_values(ascending=False)
# Out:
# Variation    20109
# client_id        0
# dtype: int64

# %%
final_experiment_nan = final_experiment.dropna()

# %%
final_experiment_nan
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %% [markdown]
# ## Merging

# %%
merged_exp_demo = pd.merge(df_final_demo, final_experiment_nan, on='client_id', how='inner')

# %%
merged_exp_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50496    6967120            21.0             260.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 50495   372100.59           6.0            9.0      Test
# 50496  4279873.38           6.0            9.0   Control
# 50497    44837.16           2.0            5.0      Test
# 50498    44994.24           1.0            4.0      Test
# 50499   209278.15           0.0            3.0      Test
#
# [50500 rows x 10 columns]

# %%
merged_exp_demo.duplicated().sum()
# Out:
# 0

# %%
merged_exp_web = pd.merge(web_df, final_experiment_nan, on='client_id', how='inner')

# %%
merged_exp_web.head(60)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0     9988021   580560515_7732621733  781255054_21935453173_531117
# 1     9988021   580560515_7732621733  781255054_21935453173_531117
# 2     9988021   580560515_7732621733  781255054_21935453173_531117
# 3     9988021   580560515_7732621733  781255054_21935453173_531117
# 4     9988021   580560515_7732621733  781255054_21935453173_531117
# 5     9988021   580560515_7732621733  781255054_21935453173_531117
# 6     9988021   580560515_7732621733  781255054_21935453173_531117
# 7     9988021   580560515_7732621733  781255054_21935453173_531117
# 8     9988021   580560515_7732621733  219729223_42518459208_211914
# 9     9988021   580560515_7732621733  219729223_42518459208_211914
# 10    9988021   580560515_7732621733  219729223_42518459208_211914
# 11    9988021   580560515_7732621733  219729223_42518459208_211914
# 12    9988021   580560515_7732621733  219729223_42518459208_211914
# 13    9988021   580560515_7732621733  219729223_42518459208_211914
# 14    9988021   580560515_7732621733  219729223_42518459208_211914
# 15    8320017   39393514_33118319366  960651974_70596002104_312201
# 16    8320017   39393514_33118319366  960651974_70596002104_312201
# 17    8320017   39393514_33118319366  960651974_70596002104_312201
# 18    8320017   39393514_33118319366  960651974_70596002104_312201
# 19    8320017   39393514_33118319366  960651974_70596002104_312201
# 20    4033851  762728880_76361333336  949661017_22392791362_127391
# 21    4033851  762728880_76361333336  949661017_22392791362_127391
# 22    4033851  762728880_76361333336  949661017_22392791362_127391
# 23    4033851  762728880_76361333336  949661017_22392791362_127391
# 24    4033851  762728880_76361333336  949661017_22392791362_127391
# 25    4033851  762728880_76361333336  949661017_22392791362_127391
# 26    4033851  762728880_76361333336  949661017_22392791362_127391
# 27    4033851  762728880_76361333336  949661017_22392791362_127391
# 28    4033851  762728880_76361333336  949661017_22392791362_127391
# 29    4033851  762728880_76361333336  949661017_22392791362_127391
# 30    4033851  762728880_76361333336  949661017_22392791362_127391
# 31    4033851  762728880_76361333336  949661017_22392791362_127391
# 32    4033851  762728880_76361333336  949661017_22392791362_127391
# 33    4033851  762728880_76361333336  949661017_22392791362_127391
# 34    4033851  762728880_76361333336  949661017_22392791362_127391
# 35    1982004  618934751_10082078917   132494692_73738638511_70823
# 36    1982004  618934751_10082078917   132494692_73738638511_70823
# 37    1982004  618934751_10082078917   132494692_73738638511_70823
# 38    1982004  618934751_10082078917   132494692_73738638511_70823
# 39    1982004  618934751_10082078917   132494692_73738638511_70823
# 40    9294070  489274391_63794562906  116640698_27328181095_188045
# 41    9294070  489274391_63794562906  116640698_27328181095_188045
# 42    9466803    97277031_5793723360   812185460_4263902139_352107
# 43    9466803    97277031_5793723360   812185460_4263902139_352107
# 44    9466803    97277031_5793723360   812185460_4263902139_352107
# 45    9466803    97277031_5793723360   812185460_4263902139_352107
# 46    9466803    97277031_5793723360   812185460_4263902139_352107
# 47    9466803    97277031_5793723360   812185460_4263902139_352107
# 48    3170143  837774974_91015515080  758001412_25057963943_219559
# 49    3170143  837774974_91015515080  758001412_25057963943_219559
# 50    3170143  837774974_91015515080  758001412_25057963943_219559
# 51    3170143  837774974_91015515080  758001412_25057963943_219559
# 52    3170143  837774974_91015515080  758001412_25057963943_219559
# 53    3170143  379063706_63772164323  276066031_50736025801_795997
# 54    3170143  379063706_63772164323  276066031_50736025801_795997
# 55    3170143  377484839_40771885547  110454357_32145786652_758657
# 56    6651403  387438258_49845138949  754106292_61370647593_160929
# 57    6651403  387438258_49845138949  754106292_61370647593_160929
# 58    6651403  387438258_49845138949  754106292_61370647593_160929
# 59    6651403  387438258_49845138949  754106292_61370647593_160929
#
#    process_step           date_time Variation
# 0        step_3 2017-04-17 15:27:07      Test
# 1        step_2 2017-04-17 15:26:51      Test
# 2        step_3 2017-04-17 15:19:22      Test
# 3        step_2 2017-04-17 15:19:13      Test
# 4        step_3 2017-04-17 15:18:04      Test
# 5        step_2 2017-04-17 15:17:15      Test
# 6        step_1 2017-04-17 15:17:01      Test
# 7         start 2017-04-17 15:16:22      Test
# 8         start 2017-04-12 18:54:43      Test
# 9         start 2017-04-12 18:38:42      Test
# 10        start 2017-04-12 18:22:40      Test
# 11        start 2017-04-12 18:06:39      Test
# 12        start 2017-04-12 17:50:38      Test
# 13        start 2017-04-12 17:34:37      Test
# 14        start 2017-04-12 16:57:27      Test
# 15      confirm 2017-04-05 13:10:05      Test
# 16       step_3 2017-04-05 13:09:43      Test
# 17       step_2 2017-04-05 13:08:40      Test
# 18       step_1 2017-04-05 13:08:24      Test
# 19        start 2017-04-05 13:08:06      Test
# 20      confirm 2017-04-05 12:29:03   Control
# 21      confirm 2017-04-05 12:29:01   Control
# 22      confirm 2017-04-05 12:28:52   Control
# 23       step_3 2017-04-05 12:26:08   Control
# 24       step_2 2017-04-05 12:24:43   Control
# 25       step_1 2017-04-05 12:24:12   Control
# 26        start 2017-04-05 12:24:04   Control
# 27       step_2 2017-04-05 12:10:26   Control
# 28       step_3 2017-04-05 12:10:26   Control
# 29       step_2 2017-04-05 12:10:25   Control
# 30       step_3 2017-04-05 12:10:25   Control
# 31       step_3 2017-04-05 12:08:56   Control
# 32       step_2 2017-04-05 12:06:37   Control
# 33       step_1 2017-04-05 12:04:56   Control
# 34        start 2017-04-05 12:04:00   Control
# 35      confirm 2017-04-17 12:02:42      Test
# 36       step_3 2017-04-17 12:01:09      Test
# 37       step_2 2017-04-17 12:00:01      Test
# 38       step_1 2017-04-17 11:59:46      Test
# 39        start 2017-04-17 11:59:42      Test
# 40        start 2017-04-17 11:16:28   Control
# 41        start 2017-04-17 11:16:13   Control
# 42        start 2017-04-16 13:24:45      Test
# 43       step_2 2017-04-16 13:24:16      Test
# 44       step_1 2017-04-16 13:24:07      Test
# 45        start 2017-04-16 13:24:05      Test
# 46       step_1 2017-04-16 13:21:58      Test
# 47        start 2017-04-16 13:21:51      Test
# 48      confirm 2017-04-04 18:41:44      Test
# 49       step_3 2017-04-04 18:41:03      Test
# 50       step_2 2017-04-04 18:38:22      Test
# 51       step_1 2017-04-04 18:38:14      Test
# 52        start 2017-04-04 18:38:02      Test
# 53       step_1 2017-04-06 12:11:19      Test
# 54        start 2017-04-06 12:10:37      Test
# 55        start 2017-04-09 09:05:26      Test
# 56      confirm 2017-04-04 17:38:39   Control
# 57       step_3 2017-04-04 17:34:03   Control
# 58       step_2 2017-04-04 17:33:55   Control
# 59       step_3 2017-04-04 17:31:32   Control

# %% [markdown]
# ## Number of accounts Control vs Test

# %%
# Count unique client_id in each Variation group
unique_clients_per_variation = merged_exp_web.groupby('Variation')['client_id'].nunique().reset_index()

# Rename columns for clarity
unique_clients_per_variation.columns = ['Variation', 'unique_client_count']

print(unique_clients_per_variation)
# Out:
#   Variation  unique_client_count
# 0   Control                16990
# 1      Test                21136

# %% [markdown]
# ## Distribution Control vs Test and Ternure

# %%
# Define bins and labels for tenure years
bins = [1, 5, 10, 20, 30, 40, merged_exp_demo["clnt_tenure_yr"].max() + 1]  # Added +1 to include the max value
labels = ['1 to 5', '6 to 10', '11 to 20', '21 to 30', '31 to 40', '41 or more']

# Create tenure categories in the DataFrame
merged_exp_demo['Clients Tenure (years)'] = pd.cut(merged_exp_demo["clnt_tenure_yr"], bins=bins, labels=labels, include_lowest=True)

# Count the number of clients in each tenure bin for each variation
tenure_distribution = merged_exp_demo.groupby(['Clients Tenure (years)', 'Variation']).size().unstack(fill_value=0)

# Define colors for each variation
colors = {'Test': 'lightgreen', 'Control': 'lightblue'}

# Plot grouped bar chart with custom colors
ax = tenure_distribution.plot(kind='bar', figsize=(12, 6), width=0.8, color=[colors[col] for col in tenure_distribution.columns])

plt.xlabel('Client Tenure (Years)')
plt.ylabel('Number of Clients')
plt.title('Distribution of Client Tenure by Variation')
plt.legend(title='Variation')
plt.grid(axis='y')

# Adjust x-tick labels for clarity
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=45)

plt.show()
# Out:
# /var/folders/jc/sd79gch55038ry1m8kx4_s440000gn/T/ipykernel_37528/1492661915.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tenure_distribution = merged_exp_demo.groupby(['Clients Tenure (years)', 'Variation']).size().unstack(fill_value=0)

# %% [markdown]
# ## Table Visit Duration

# %%
# Function to calculate the visit duration and return the first variation
def visit_info(group):
    start_time = group['date_time'].min()
    end_time = group['date_time'].max()
    duration = end_time - start_time
    variation = group['Variation'].iloc[0]
    return pd.Series({'visit_duration': duration, 'Variation': variation})

# Group by visit_id and calculate the duration and variation
visit_durations = merged_exp_web.groupby('visit_id').apply(visit_info).reset_index()
visit_durations
# Out:
#                            visit_id  visit_duration Variation
# 0      100012776_37918976071_457913 0 days 00:00:52      Test
# 1       100019538_17884295066_43909 0 days 00:04:02      Test
# 2      100022086_87870757897_149620 0 days 00:03:00      Test
# 3      100030127_47967100085_936361 0 days 00:00:00   Control
# 4      100037962_47432393712_705583 0 days 00:02:12   Control
# ...                             ...             ...       ...
# 69200  999971096_28827267783_236076 0 days 00:02:19      Test
# 69201  999976049_95772503197_182554 0 days 00:12:08      Test
# 69202  999984454_18731538378_781808 0 days 00:02:34      Test
# 69203  999985675_64610694964_443659 0 days 00:17:30   Control
# 69204  999988789_76411676596_272843 0 days 00:01:58      Test
#
# [69205 rows x 3 columns]

# %% [markdown]
# ## Completion Rate

# %%
pivot_table = pd.pivot_table(
    merged_exp_web,
    index='visit_id',
    columns='process_step',
    aggfunc='size',
    fill_value=0
).reset_index()

ordered_columns = ['start', 'step_1', 'step_2', 'step_3', 'confirm']
pivot_table = pivot_table[['visit_id'] + ordered_columns]

pivot_table
# Out:
# process_step                      visit_id  start  step_1  step_2  step_3  \
# 0             100012776_37918976071_457913      0       0       0       0
# 1              100019538_17884295066_43909      3       4       2       1
# 2             100022086_87870757897_149620      1       1       1       1
# 3             100030127_47967100085_936361      1       0       0       0
# 4             100037962_47432393712_705583      3       1       0       0
# ...                                    ...    ...     ...     ...     ...
# 69200         999971096_28827267783_236076      1       2       1       1
# 69201         999976049_95772503197_182554      1       1       1       2
# 69202         999984454_18731538378_781808      1       1       1       1
# 69203         999985675_64610694964_443659      1       1       1       1
# 69204         999988789_76411676596_272843      2       2       1       0
#
# process_step  confirm
# 0                   2
# 1                   1
# 2                   1
# 3                   0
# 4                   0
# ...               ...
# 69200               1
# 69201               1
# 69202               1
# 69203               1
# 69204               0
#
# [69205 rows x 6 columns]

# %%
#drop null values
#does the customers need to pass all steps?
#completion is the count after cleaning the null??

# %%
# Count the number of rows where 'confirm' is greater than 0
count_confirm_greater_than_0 = (pivot_table['confirm'] > 0).sum()

# Display the result
print(f"Number of visits that reached 'confirm': {count_confirm_greater_than_0}")
# Out:
# Number of visits that reached 'confirm': 37680

# %%
completion_rate_total = (37680/69205) *100
completion_rate_total
# Out:
# 54.44693302507044

# %%
# Extract the first Variation for each visit_id
variation_map = merged_exp_web.groupby('visit_id')['Variation'].first()

# Add the Variation column to the pivot table
pivot_table['Variation'] = pivot_table['visit_id'].map(variation_map)

pivot_table
# Out:
# process_step                      visit_id  start  step_1  step_2  step_3  \
# 0             100012776_37918976071_457913      0       0       0       0
# 1              100019538_17884295066_43909      3       4       2       1
# 2             100022086_87870757897_149620      1       1       1       1
# 3             100030127_47967100085_936361      1       0       0       0
# 4             100037962_47432393712_705583      3       1       0       0
# ...                                    ...    ...     ...     ...     ...
# 69200         999971096_28827267783_236076      1       2       1       1
# 69201         999976049_95772503197_182554      1       1       1       2
# 69202         999984454_18731538378_781808      1       1       1       1
# 69203         999985675_64610694964_443659      1       1       1       1
# 69204         999988789_76411676596_272843      2       2       1       0
#
# process_step  confirm Variation
# 0                   2      Test
# 1                   1      Test
# 2                   1      Test
# 3                   0   Control
# 4                   0   Control
# ...               ...       ...
# 69200               1      Test
# 69201               1      Test
# 69202               1      Test
# 69203               1   Control
# 69204               0      Test
#
# [69205 rows x 7 columns]

# %%
# Filter to get only rows where process_step is 'confirm'
confirm_df = merged_exp_web[merged_exp_web['process_step'] == 'confirm']

# Group by Variation to get the number of users who reached 'confirm'
confirm_counts = confirm_df.groupby('Variation')['visit_id'].nunique()

# Group by Variation to get the total number of users
total_counts = merged_exp_web.groupby('Variation')['visit_id'].nunique()

# Calculate the completion rate
completion_rate = (confirm_counts / total_counts).reset_index()
completion_rate.columns = ['Variation', 'Completion_Rate']

# Display the completion rate
print(completion_rate)
# Out:
#   Variation  Completion_Rate
# 0   Control         0.498493
# 1      Test         0.585173

# %% [markdown]
# ## Error Rate

# %%
# Sort by visit_id and date_time
merged_exp_web = merged_exp_web.sort_values(by=['visit_id', 'date_time'])

# Map process_step to numerical values
step_mapping = {'start': 1, 'step_1': 2, 'step_2': 3, 'step_3': 4, 'confirm': 5}
merged_exp_web['step_num'] = merged_exp_web['process_step'].map(step_mapping)

# Calculate backward steps
merged_exp_web['prev_step_num'] = merged_exp_web.groupby('visit_id')['step_num'].shift(1)
merged_exp_web['backward_step'] = merged_exp_web['step_num'] < merged_exp_web['prev_step_num']

# Calculate total steps and backward steps for each group
error_stats = merged_exp_web.groupby('Variation').agg(
    total_steps=('step_num', 'count'),
    backward_steps=('backward_step', 'sum')
).reset_index()

# Calculate error rate
error_stats['error_rate'] = error_stats['backward_steps'] / error_stats['total_steps']

# Display the error rate for each group
print(error_stats[['Variation', 'error_rate']])
# Out:
#   Variation  error_rate
# 0   Control    0.067851
# 1      Test    0.091961

# %% [markdown]
# The .shift(1) function is used to align the previous row's value next to the current row's value, enabling comparisons between consecutive rows within each group. This is essential for identifying backward steps in the process.

# %% [markdown]
# ## Time Spent on Each Step

# %%
# Sort by visit_id and date_time
merged_exp_web = merged_exp_web.sort_values(by=['visit_id', 'date_time'])

# Calculate the time difference between consecutive steps
merged_exp_web['time_diff'] = merged_exp_web.groupby('visit_id')['date_time'].diff()

# Remove the first step (as it doesn't have a previous step to compare with)
merged_exp_web = merged_exp_web.dropna(subset=['time_diff'])

# Calculate the average time spent on each step for each variation
average_time_per_step = merged_exp_web.groupby(['Variation', 'process_step'])['time_diff'].mean().reset_index()

# Display the result
print(average_time_per_step)
# Out:
#   Variation process_step                 time_diff
# 0   Control      confirm 0 days 00:02:06.265021392
# 1   Control        start 0 days 00:03:21.288349287
# 2   Control       step_1 0 days 00:02:06.827923429
# 3   Control       step_2 0 days 00:00:42.487359760
# 4   Control       step_3 0 days 00:01:25.384280801
# 5      Test      confirm 0 days 00:02:05.302940046
# 6      Test        start 0 days 00:03:00.213124715
# 7      Test       step_1 0 days 00:01:28.125858752
# 8      Test       step_2 0 days 00:01:04.458972046
# 9      Test       step_3 0 days 00:01:44.755760759

# %% [markdown]
# ## Client behavior analysis

# %% [markdown]
# From the clients using the online process, how is the demografic distribution?
# younger or older, new or long-standing?

# %%
#online vs calls
#calls_6_mnth	logons_6_mnth
